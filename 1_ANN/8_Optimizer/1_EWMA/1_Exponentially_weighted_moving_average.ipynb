# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DailyDelhiClimate.csv',usecols=['date','meantemp'])
df = df.iloc[:115,:]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')

# %%
x1 = df['meantemp'].ewm(alpha=0.9).mean()

# %%
x1
# Out:
# 0      10.000000
# 1       7.636364
# 2       7.213213
# 3       8.521452
# 4       6.252123
#          ...
# 110    27.941024
# 111    27.431602
# 112    28.505660
# 113    30.107709
# 114    31.039342
# Name: meantemp, Length: 115, dtype: float64

# %%
df['x1'] = x1
df
# Out:
#            date   meantemp         x1
# 0    2013-01-01  10.000000  10.000000
# 1    2013-01-02   7.400000   7.636364
# 2    2013-01-03   7.166667   7.213213
# 3    2013-01-04   8.666667   8.521452
# 4    2013-01-05   6.000000   6.252123
# ..          ...        ...        ...
# 110  2013-04-21  27.666667  27.941024
# 111  2013-04-22  27.375000  27.431602
# 112  2013-04-23  28.625000  28.505660
# 113  2013-04-24  30.285714  30.107709
# 114  2013-04-25  31.142857  31.039342
#
# [115 rows x 3 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black')
